# %% [markdown]
# ### Setup

# %%
# %pip install jax equinox treescope
import jax
import jax.numpy as jnp
import equinox as eqx
import treescope
# Out:
# Requirement already satisfied: jax in /Users/eringrant/mambaforge/envs/asysid/lib/python3.13/site-packages (0.4.38)
# Requirement already satisfied: equinox in /Users/eringrant/mambaforge/envs/asysid/lib/python3.13/site-packages (0.11.11)
# Requirement already satisfied: treescope in /Users/eringrant/mambaforge/envs/asysid/lib/python3.13/site-packages (0.1.7)
# Requirement already satisfied: jaxlib<=0.4.38,>=0.4.38 in /Users/eringrant/mambaforge/envs/asysid/lib/python3.13/site-packages (from jax) (0.4.38)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /Users/eringrant/mambaforge/envs/asysid/lib/python3.13/site-packages (from jax) (0.5.0)
# Requirement already satisfied: numpy>=1.24 in /Users/eringrant/mambaforge/envs/asysid/lib/python3.13/site-packages (from jax) (2.2.1)
# Requirement already satisfied: opt_einsum in /Users/eringrant/mambaforge/envs/asysid/lib/python3.13/site-packages (from jax) (3.4.0)
# Requirement already satisfied: scipy>=1.10 in /Users/eringrant/mambaforge/envs/asysid/lib/python3.13/site-packages (from jax) (1.15.0)
# Requirement already satisfied: jaxtyping>=0.2.20 in /Users/eringrant/mambaforge/envs/asysid/lib/python3.13/site-packages (from equinox) (0.2.36)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/eringrant/mambaforge/envs/asysid/lib/python3.13/site-packages (from equinox) (4.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from expand import scale_neurons
from expand import duplicate_neurons
from expand import add_random_zero_neurons
from expand import add_phantom_zero_neurons

def get_output(model, inputs, key):
    return model(inputs, key=key)

def get_preacts(model, inputs, key):
    return model.layers[0](inputs, key=key)

def get_postacts(model, inputs, key):
    return model.activation(get_preacts(model, inputs, key))

def mse(pred_y, y):
    return jnp.mean(jnp.sum(jnp.square((pred_y - y)), axis=1), axis=0)

# %% [markdown]
# ### XOR

# %%
from xor import train_xor
xor_model = train_xor()
xor_model
# Out:
# Evaluating iteration with loss value 0.5622677803039551.
# Evaluating iteration with loss value 0.5441693067550659.
# Evaluating iteration with loss value 0.5289270877838135.
# Evaluating iteration with loss value 0.5156916379928589.
# Evaluating iteration with loss value 0.5038694143295288.
# Evaluating iteration with loss value 0.49303457140922546.
# Evaluating iteration with loss value 0.48287567496299744.
# Evaluating iteration with loss value 0.4731637239456177.
# Evaluating iteration with loss value 0.46373170614242554.
# Evaluating iteration with loss value 0.4544614553451538.
# Evaluating iteration with loss value 0.44527554512023926.
# Evaluating iteration with loss value 0.4361308813095093.
# Evaluating iteration with loss value 0.42701467871665955.
# Evaluating iteration with loss value 0.417940229177475.
# Evaluating iteration with loss value 0.40894317626953125.
# Evaluating iteration with loss value 0.40007680654525757.
# Evaluating iteration with loss value 0.39140695333480835.
# Evaluating iteration with loss value 0.38300657272338867.
# Evaluating iteration with loss value 0.3749493360519409.
# Evaluating iteration with loss value 0.3673039674758911.
# Evaluating iteration with loss value 0.3601287305355072.
# Evaluating iteration with loss value 0.35346710681915283.
# Evaluating iteration with loss value 0.34734514355659485.
# Evaluating iteration with loss value 0.3417702913284302.
# Evaluating iteration with loss value 0.33673205971717834.
# Evaluating iteration with loss value 0.3322039544582367.
# Evaluating iteration with loss value 0.3281468451023102.
# Evaluating iteration with loss value 0.3245123326778412.
# Evaluating iteration with loss value 0.3212467133998871.
# Evaluating iteration with loss value 0.3182942867279053.
# Evaluating iteration with loss value 0.31560051441192627.
# Evaluating iteration with loss value 0.3131137490272522.
# Evaluating iteration with loss value 0.3107869029045105.
# Evaluating iteration with loss value 0.3085784316062927.
# Evaluating iteration with loss value 0.30645230412483215.
# Evaluating iteration with loss value 0.3043779730796814.
# Evaluating iteration with loss value 0.3023301661014557.
# Evaluating iteration with loss value 0.3002881705760956.
# Evaluating iteration with loss value 0.2982352375984192.
# Evaluating iteration with loss value 0.2961581349372864.
# Evaluating iteration with loss value 0.29404667019844055.
# Evaluating iteration with loss value 0.29189300537109375.
# Evaluating iteration with loss value 0.28969138860702515.
# Evaluating iteration with loss value 0.2874375879764557.
# Evaluating iteration with loss value 0.2851290702819824.
# Evaluating iteration with loss value 0.28276437520980835.
# Evaluating iteration with loss value 0.28034305572509766.
# Evaluating iteration with loss value 0.27786555886268616.
# Evaluating iteration with loss value 0.27533307671546936.
# Evaluating iteration with loss value 0.27274760603904724.
# Evaluating iteration with loss value 0.270111620426178.
# Evaluating iteration with loss value 0.2674281895160675.
# Evaluating iteration with loss value 0.2647009491920471.
# Evaluating iteration with loss value 0.26193395256996155.
# Evaluating iteration with loss value 0.2591315805912018.
# Evaluating iteration with loss value 0.25629866123199463.
# Evaluating iteration with loss value 0.253440260887146.
# Evaluating iteration with loss value 0.25056177377700806.
# Evaluating iteration with loss value 0.24766869843006134.
# Evaluating iteration with loss value 0.24476666748523712.
# Evaluating iteration with loss value 0.2418614625930786.
# Evaluating iteration with loss value 0.23895877599716187.
# Evaluating iteration with loss value 0.2369593381881714.
# Evaluating iteration with loss value 0.23507586121559143.
# Evaluating iteration with loss value 0.23218083381652832.
# Evaluating iteration with loss value 0.22988280653953552.
# Evaluating iteration with loss value 0.22841602563858032.
# Evaluating iteration with loss value 0.22555145621299744.
# Evaluating iteration with loss value 0.22272926568984985.
# Evaluating iteration with loss value 0.22192445397377014.
# Evaluating iteration with loss value 0.219110369682312.
# Evaluating iteration with loss value 0.21634143590927124.
# Evaluating iteration with loss value 0.21481919288635254.
# Evaluating iteration with loss value 0.21299271285533905.
# Evaluating iteration with loss value 0.21029140055179596.
# Evaluating iteration with loss value 0.2076469361782074.
# Evaluating iteration with loss value 0.20690302550792694.
# Evaluating iteration with loss value 0.20457659661769867.
# Evaluating iteration with loss value 0.20200665295124054.
# Evaluating iteration with loss value 0.19950063526630402.
# Evaluating iteration with loss value 0.1989234834909439.
# Evaluating iteration with loss value 0.19668656587600708.
# Evaluating iteration with loss value 0.19425272941589355.
# Evaluating iteration with loss value 0.1918858140707016.
# Evaluating iteration with loss value 0.19082748889923096.
# Evaluating iteration with loss value 0.189289391040802.
# Evaluating iteration with loss value 0.18698538839817047.
# Evaluating iteration with loss value 0.18474753201007843.
# Evaluating iteration with loss value 0.18257510662078857.
# Evaluating iteration with loss value 0.18232092261314392.
# Evaluating iteration with loss value 0.18013237416744232.
# Evaluating iteration with loss value 0.17800664901733398.
# Evaluating iteration with loss value 0.17593884468078613.
# Evaluating iteration with loss value 0.1739242672920227.
# Evaluating iteration with loss value 0.17367731034755707.
# Evaluating iteration with loss value 0.1717776209115982.
# Evaluating iteration with loss value 0.16977037489414215.
# Evaluating iteration with loss value 0.1678137332201004.
# Evaluating iteration with loss value 0.16590209305286407.
# Evaluating iteration with loss value 0.16431131958961487.
# Evaluating iteration with loss value 0.1638285517692566.
# Evaluating iteration with loss value 0.1619018167257309.
# Evaluating iteration with loss value 0.16001750528812408.
# Evaluating iteration with loss value 0.15816988050937653.
# Evaluating iteration with loss value 0.1563536822795868.
# Evaluating iteration with loss value 0.15456409752368927.
# Evaluating iteration with loss value 0.15396201610565186.
# Evaluating iteration with loss value 0.15255053341388702.
# Evaluating iteration with loss value 0.15070916712284088.
# Evaluating iteration with loss value 0.1488959640264511.
# Evaluating iteration with loss value 0.14710566401481628.
# Evaluating iteration with loss value 0.14533363282680511.
# Evaluating iteration with loss value 0.14357580244541168.
# Evaluating iteration with loss value 0.14247003197669983.
# Evaluating iteration with loss value 0.1415044665336609.
# Evaluating iteration with loss value 0.1396755874156952.
# Evaluating iteration with loss value 0.1378655880689621.
# Evaluating iteration with loss value 0.13606975972652435.
# Evaluating iteration with loss value 0.1342841237783432.
# Evaluating iteration with loss value 0.13250517845153809.
# Evaluating iteration with loss value 0.1307300329208374.
# Evaluating iteration with loss value 0.1296343356370926.
# Evaluating iteration with loss value 0.12824313342571259.
# Evaluating iteration with loss value 0.12559986114501953.
# Evaluating iteration with loss value 0.12303949892520905.
# Evaluating iteration with loss value 0.12054570019245148.
# Evaluating iteration with loss value 0.11810442060232162.
# Evaluating iteration with loss value 0.11570372432470322.
# Evaluating iteration with loss value 0.1133335530757904.
# Evaluating iteration with loss value 0.11098539084196091.
# Evaluating iteration with loss value 0.10865230858325958.
# Evaluating iteration with loss value 0.1063285619020462.
# Evaluating iteration with loss value 0.10451866686344147.
# Evaluating iteration with loss value 0.10232087224721909.
# Evaluating iteration with loss value 0.09988709539175034.
# Evaluating iteration with loss value 0.0974697694182396.
# Evaluating iteration with loss value 0.0950642079114914.
# Evaluating iteration with loss value 0.09266681969165802.
# Evaluating iteration with loss value 0.09027493000030518.
# Evaluating iteration with loss value 0.08788671344518661.
# Evaluating iteration with loss value 0.0855010449886322.
# Evaluating iteration with loss value 0.08311747014522552.
# Evaluating iteration with loss value 0.08073604106903076.
# Evaluating iteration with loss value 0.0783572867512703.
# Evaluating iteration with loss value 0.0759822204709053.
# Evaluating iteration with loss value 0.07361212372779846.
# Evaluating iteration with loss value 0.07124870270490646.
# Evaluating iteration with loss value 0.06889386475086212.
# Evaluating iteration with loss value 0.06654980033636093.
# Evaluating iteration with loss value 0.06421887874603271.
# Evaluating iteration with loss value 0.06190362945199013.
# Evaluating iteration with loss value 0.059606749564409256.
# Evaluating iteration with loss value 0.0005398461362347007.
# Evaluating iteration with loss value 0.0004898328334093094.
# Evaluating iteration with loss value 0.00044432212598621845.
# Evaluating iteration with loss value 0.0004029255360364914.
# Evaluating iteration with loss value 0.0003652885206975043.
# Evaluating iteration with loss value 0.00033108078059740365.
# Evaluating iteration with loss value 0.00030000245897099376.
# Evaluating iteration with loss value 0.00027177753509022295.
# Evaluating iteration with loss value 0.00024615239817649126.
# Evaluating iteration with loss value 0.00022289680782705545.
# Evaluating iteration with loss value 0.00020179685088805854.
# Evaluating iteration with loss value 0.00018265889957547188.
# Evaluating iteration with loss value 0.000165305013069883.
# Evaluating iteration with loss value 0.00014957290841266513.
# Evaluating iteration with loss value 0.00013531616423279047.
# Evaluating iteration with loss value 0.000122397905215621.
# Evaluating iteration with loss value 0.00011069652100559324.
# Evaluating iteration with loss value 0.00010009827383328229.
# Evaluating iteration with loss value 9.050294465851039e-05.
# Evaluating iteration with loss value 8.181702287402004e-05.
# Evaluating iteration with loss value 7.395537249976769e-05.
# Evaluating iteration with loss value 6.684055551886559e-05.
# Evaluating iteration with loss value 6.040332664269954e-05.
# Evaluating iteration with loss value 5.4579999414272606e-05.
# Evaluating iteration with loss value 4.931339935865253e-05.
# Evaluating iteration with loss value 4.455101952771656e-05.
# Evaluating iteration with loss value 4.024467489216477e-05.
# Evaluating iteration with loss value 3.6351084418129176e-05.
# Evaluating iteration with loss value 3.2831587304826826e-05.
# Evaluating iteration with loss value 2.9650191208929755e-05.
# Evaluating iteration with loss value 2.6775167498271912e-05.
# Evaluating iteration with loss value 2.4176890292437747e-05.
# Evaluating iteration with loss value 2.1829586330568418e-05.
# Evaluating iteration with loss value 1.970855191757437e-05.
# Evaluating iteration with loss value 1.779277044988703e-05.
# Evaluating iteration with loss value 1.6062007489381358e-05.
# Evaluating iteration with loss value 1.4499008102575317e-05.
# Evaluating iteration with loss value 1.3087439583614469e-05.
# Evaluating iteration with loss value 1.1812519915110897e-05.
# Evaluating iteration with loss value 1.0661498890840448e-05.
# Evaluating iteration with loss value 9.622232028050348e-06.
# Evaluating iteration with loss value 8.683638043294195e-06.
# Evaluating iteration with loss value 7.836476470401976e-06.
# Evaluating iteration with loss value 7.071665095281787e-06.
# Evaluating iteration with loss value 6.381249477271922e-06.
# Evaluating iteration with loss value 5.757969574915478e-06.
# Found solution with loss value 5.757969574915478e-06.
# MLP(
#   layers=(
#     Linear(
#       weight=f32[2,2],
#       bias=None,
#       in_features=2,
#       out_features=2,
#       use_bias=False
#     ),
#     Linear(
#       weight=f32[1,2],
#       bias=None,
#       in_features=2,
#       out_features=1,
#       use_bias=False
#     )
#   ),
#   activation=<wrapped function relu>,
#   final_activation=<function <lambda>>,
#   use_bias=False,
#   use_final_bias=False,
#   in_size=2,
#   out_size=1,
#   width_size=2,
#   depth=1
# )

# %%
batch_size = 2
data_key = jax.random.PRNGKey(0)
x = jax.random.normal(data_key, (batch_size, 2))
treescope.render_array(
    x,
    pixels_per_cell=8,
# Iteration 69, loss: 0.554851233959198
# Iteration 70, loss: 0.5378676652908325
# Iteration 71, loss: 0.5214664340019226
# Iteration 72, loss: 0.505624532699585
# Iteration 73, loss: 0.4903278052806854
# Iteration 74, loss: 0.4755377173423767
# Iteration 75, loss: 0.4612431824207306
# Iteration 76, loss: 0.4474264085292816
# Iteration 77, loss: 0.43406274914741516
# Iteration 78, loss: 0.4211435317993164
# Iteration 79, loss: 0.4086463153362274
# Iteration 80, loss: 0.39656639099121094
# Iteration 81, loss: 0.38488826155662537
# Iteration 82, loss: 0.3735847771167755
# Iteration 83, loss: 0.3626459836959839
# Iteration 84, loss: 0.35205793380737305
# Iteration 85, loss: 0.34181535243988037
# Iteration 86, loss: 0.33189553022384644
# Iteration 87, loss: 0.3222911059856415
# Iteration 88, loss: 0.31298133730888367
# Iteration 89, loss: 0.3039696216583252
# Iteration 90, loss: 0.29523831605911255
# Iteration 91, loss: 0.2867772579193115
# Iteration 92, loss: 0.278569757938385
# Iteration 93, loss: 0.2706209421157837
# Iteration 94, loss: 0.26292547583580017
# Iteration 95, loss: 0.25546973943710327
# Iteration 96, loss: 0.24825182557106018
# Iteration 97, loss: 0.24126291275024414
# Iteration 98, loss: 0.2344944030046463
# Iteration 99, loss: 0.227945014834404
# MLP(
#   layers=(
#     Linear(
#       weight=f32[512,784],
#       bias=None,
#       in_features=784,
#       out_features=512,
#       use_bias=False
#     ),
#     Linear(
#       weight=f32[512,512],
#       bias=None,
#       in_features=512,
#       out_features=512,
#       use_bias=False
#     ),
#     Linear(
#       weight=f32[10,512],
#       bias=None,
#       in_features=512,
#       out_features=10,
#       use_bias=False
#     )
#   ),
#   activation=<wrapped function relu>,
#   final_activation=<function <lambda>>,
#   use_bias=False,
#   use_final_bias=False,
#   in_size=784,
#   out_size=10,
#   width_size=512,
#   depth=2
# )

# %%
pattern_size = 2
random_pattern_key = jax.random.PRNGKey(1)
random_pattern = jax.random.normal(random_pattern_key, (batch_size, pattern_size))
random_pattern = jax.nn.relu(random_pattern)
treescope.render_array(
    random_pattern,
    pixels_per_cell=8,
    axis_labels={0: "input example", 1: "phantom dimension"},
    vmax=1, vmin=-1,
)
# Out:
# <Arrayviz rendering>

# %%
pattern_size = 512
random_pattern_key = jax.random.PRNGKey(1)
random_pattern = jax.random.normal(random_pattern_key, (batch_size, pattern_size))
random_pattern = jax.nn.relu(random_pattern)
treescope.render_array(
    random_pattern,
    pixels_per_cell=1,
    axis_labels={0: "input example", 1: "phantom dimension"},
    vmax=1, vmin=-1,
)
# Out:
# <Arrayviz rendering>

# %%
W1 = xor_model.layers[0].weight
W2 = xor_model.layers[1].weight

forward_key = jax.random.PRNGKey(2)
preacts = eqx.filter_vmap(get_preacts, in_axes=(None, 0, None))(xor_model, x, forward_key)
new_W1, new_W2 = add_phantom_zero_neurons(W1, W2, preacts, random_pattern)

new_xor_model = eqx.tree_at(lambda x: x.layers[0].weight, xor_model, new_W1)
new_xor_model = eqx.tree_at(lambda x: x.layers[1].weight, new_xor_model, new_W2)

original_outputs = eqx.filter_vmap(get_output, in_axes=(None, 0, None))(xor_model, x, forward_key)
new_outputs = eqx.filter_vmap(get_output, in_axes=(None, 0, None))(new_xor_model, x, forward_key)
print(f"Difference in outputs: {mse(original_outputs, new_outputs)}")

original_activities = eqx.filter_vmap(get_postacts, in_axes=(None, 0, None))(xor_model, x, forward_key)
new_activities = eqx.filter_vmap(get_postacts, in_axes=(None, 0, None))(new_xor_model, x, forward_key)
phantom_activities = new_activities[:, -pattern_size:]
print(f"Difference of internal activities to pattern: {mse(random_pattern, phantom_activities)}")

treescope.render_array(
    phantom_activities,
    pixels_per_cell=8,
    axis_labels={0: "input example", 1: "phantom dimension"},
    vmax=1, vmin=-1,
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       2 W2 = xor_model.layers[1].weight
#       4 forward_key = jax.random.PRNGKey(2)
# ----> 5 preacts = eqx.filter_vmap(get_preacts, in_axes=(None, 0, None))(xor_model, x, forward_key)
#       6 new_W1, new_W2 = add_phantom_zero_neurons(W1, W2, preacts, random_pattern)
#       8 new_xor_model = eqx.tree_at(lambda x: x.layers[0].weight, xor_model, new_W1)
#
# File ~/mambaforge/envs/asysid/lib/python3.13/site-packages/equinox/_vmap_pmap.py:169, in _VmapWrapper.__call__(***failed resolving arguments***)
#     164         raise ValueError(
#     165             "Cannot resolve batch dimension. Non-`None` `out_axes` requires "
#     166             "either `in_axes` or `axis_size` to be not `None`."
#     167         )
#     168 else:
# --> 169     vmapd, nonvmapd_arr, static = jax.vmap(
#     170         _fun_wrapper,
#     171         in_axes=(in_axes,),
#     172         out_axes=(0, None, None),
#     173         axis_name=self._axis_name,
#     174         axis_size=self._axis_size,
#     175         **self._vmapkwargs,
#     176     )(dynamic_args)
#     178 nonvmapd_static, out_axes = static.value
#     179 nonvmapd = combine(nonvmapd_arr, nonvmapd_static)
#
#     [... skipping hidden 7 frame]
#
# Cell In[2], line 10, in get_preacts(model, inputs, key)
#       9 def get_preacts(model, inputs, key):
# ---> 10     return model.layers[0](inputs, key=key)
#
# File ~/mambaforge/envs/asysid/lib/python3.13/contextlib.py:85, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      82 @wraps(func)
#      83 def inner(*args, **kwds):
#      84     with self._recreate_cm():
# ---> 85         return func(*args, **kwds)
#
# File ~/mambaforge/envs/asysid/lib/python3.13/site-packages/equinox/nn/_linear.py:95, in Linear.__call__(self, x, key)
#      93         raise ValueError("x must have scalar shape")
#      94     x = jnp.broadcast_to(x, (1,))
# ---> 95 x = self.weight @ x
#      96 if self.bias is not None:
#      97     x = x + self.bias
#
# File ~/mambaforge/envs/asysid/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:573, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     571 args = (other, self) if swap else (self, other)
#     572 if isinstance(other, _accepted_binop_types):
# --> 573   return binary_op(*args)
#     574 # Note: don't use isinstance here, because we don't want to raise for
#     575 # subclasses, e.g. NamedTuple objects that may override operators.
#     576 if type(other) in _rejected_binop_types:
#
#     [... skipping hidden 14 frame]
#
# File ~/mambaforge/envs/asysid/lib/python3.13/site-packages/jax/_src/numpy/lax_numpy.py:9161, in matmul(a, b, precision, preferred_element_type)
#    9159 a = lax.squeeze(a, tuple(a_squeeze))
#    9160 b = lax.squeeze(b, tuple(b_squeeze))
# -> 9161 out = lax.dot_general(
#    9162   a, b, (((ndim(a) - 1,), (ndim(b) - 1 - b_is_mat,)), (a_batch, b_batch)),
#    9163   precision=precision, preferred_element_type=preferred_element_type)
#    9164 result = lax.transpose(out, perm)
#    9165 return lax_internal._convert_element_type(result, preferred_element_type, output_weak_type)
#
#     [... skipping hidden 7 frame]
#
# File ~/mambaforge/envs/asysid/lib/python3.13/site-packages/jax/_src/lax/lax.py:3342, in _dot_general_shape_rule(lhs, rhs, dimension_numbers, precision, preferred_element_type, out_type)
#    3339 if not core.definitely_equal_shape(lhs_contracting_shape, rhs_contracting_shape):
#    3340   msg = ("dot_general requires contracting dimensions to have the same "
#    3341          "shape, got {} and {}.")
# -> 3342   raise TypeError(msg.format(lhs_contracting_shape, rhs_contracting_shape))
#    3344 return _dot_general_shape_computation(lhs.shape, rhs.shape, dimension_numbers)
#
# TypeError: dot_general requires contracting dimensions to have the same shape, got (2,) and (784,).

# %%
W1 = mnist_model.layers[0].weight
W2 = mnist_model.layers[1].weight

forward_key = jax.random.PRNGKey(2)
preacts = eqx.filter_vmap(get_preacts, in_axes=(None, 0, None))(mnist_model, x, forward_key)
new_W1, new_W2 = add_phantom_zero_neurons(W1, W2, preacts, random_pattern)

new_mnist_model = eqx.tree_at(lambda x: x.layers[0].weight, mnist_model, new_W1)
new_mnist_model = eqx.tree_at(lambda x: x.layers[1].weight, new_mnist_model, new_W2)

original_outputs = eqx.filter_vmap(get_output, in_axes=(None, 0, None))(mnist_model, x, forward_key)
new_outputs = eqx.filter_vmap(get_output, in_axes=(None, 0, None))(new_mnist_model, x, forward_key)
print(f"Difference in outputs: {mse(original_outputs, new_outputs)}")

original_activities = eqx.filter_vmap(get_postacts, in_axes=(None, 0, None))(mnist_model, x, forward_key)
new_activities = eqx.filter_vmap(get_postacts, in_axes=(None, 0, None))(new_mnist_model, x, forward_key)
phantom_activities = new_activities[:, -pattern_size:]
print(f"Difference of internal activities to pattern: {mse(random_pattern, phantom_activities)}")

treescope.render_array(
    phantom_activities,
    pixels_per_cell=8,
    axis_labels={0: "input example", 1: "phantom dimension"},
    vmax=1, vmin=-1,
)

# %%
new_mnist_model

# %%
treescope.render_array(
    original_activities,
    pixels_per_cell=8,
    axis_labels={0: "input example", 1: "original activities"},
    vmax=1, vmin=-1,
)

# %%
treescope.render_array(
    new_activities,
    pixels_per_cell=8,
    axis_labels={0: "input example", 1: "expanded activities"},
    vmax=1, vmin=-1,
)

# %% [markdown]
# ### MNIST

# %%
batch_size = 128
data_key = jax.random.PRNGKey(0)
# TODO: use mnist validation data
x = jax.random.normal(data_key, (batch_size, 28 * 28))
treescope.render_array(
    x,
    pixels_per_cell=1,
    axis_labels={0: "input example", 1: "input dimension"},
    vmax=1, vmin=-1,
)
# Out:
# <Arrayviz rendering>
