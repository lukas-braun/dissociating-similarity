# %%
# %load_ext autoreload
# %autoreload 2

import dissociation as ds
import numpy as np
import matplotlib.pyplot as plt

plt.style.use("./style.mplstyle")
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
fig, axs = plt.subplots(1, 2, figsize=(1.6*1.8, 1.6))
axs = axs.flatten()

ax = axs[0]

ax.plot(range(11), range(11))

ax.set_ylim(-0.05, 1.05)
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, "", 1])

ax.set_xticks([0, 10])
ax.set_xticklabels([0, 10])

ax.set_title("Blie")
ax.set_xlabel("Step", labelpad=-5)
ax.set_ylabel("$R^2$", labelpad=-5)


ax = axs[1]

ax.plot(range(11), range(11))
ax.plot(range(1, 12), range(11))
ax.plot(range(2, 13), range(11))

ax.set_ylim(-0.05, 1.05)
ax.set_yticks([0, 0.5, 1])
ax.set_yticklabels([0, "", 1])

ax.set_xticks([0, 10])
ax.set_xticklabels([0, 10])

ax.set_title("Bla")
ax.set_xlabel("Step", labelpad=-5)
ax.set_ylabel("$R^2$", labelpad=-5)
# Out:
# Text(0, 0.5, '$R^2$')

# %%
fig, ax = plt.subplots()
ax.imshow(np.random.normal(0., 1., (5, 5)))
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
